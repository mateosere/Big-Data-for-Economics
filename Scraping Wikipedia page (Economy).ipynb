# %% [markdown]
# # Scraping - The hard way

# %%
from requests_html import HTMLSession
session = HTMLSession()
url = 'https://en.wikipedia.org/wiki/Economics'
r = session.get(url)
r.status_code

# %% [markdown]
# ![statuscode.png](attachment:statuscode.png)

# %%
r.html
r.html.text
html.find('title')
html.find('title')[0].text

html.find('h1')
html.find('h1')[0].text

html.find('h2')
html.find('h2')[0].text

html.find('.firstHeading')
html.find('.firstHeading')[0].text

html.find('.mw-headline')
html.find('.mw-headline')[0].text

for item in html.find('p'):
    print(item.text)
    
for item in html.find('[role=note]'):
    print(item.text)
    
for item in html.find('.reference-text'):
    print(item.text)
    
for item in html.find('.reference-text'):
    print(item.absolute_links)
    
html.absolute_links
